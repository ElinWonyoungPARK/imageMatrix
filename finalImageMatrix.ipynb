# %%
import numpy as np
import matplotlib.pyplot as plt

vertical = 1080
horizontal = 1920
my_dpi = 100

intervals = [19,10,7]
colors = [
    [0.2, 0.9, 0.2],
    [0.3, 0.3, 0.3],
    [0.8, 0.4, 0.4],
]   
baseImg1 = np.full((vertical,horizontal,3),(255,255,255))

# %%
#horizontal pattern
def createBaseImg(vertical, horizontal):
    imgMatrix = np.full((vertical,horizontal,3),(255,255,255))
    return imgMatrix

def cutImg(imgMatrix,n,interval):
    subImgMatrix = imgMatrix[:,n:n+interval]
    return subImgMatrix

def coloring(subImgMatrix,color):
     subImgMatrix = subImgMatrix * color
     return subImgMatrix

def drawPattern(imgMatrix,intervals,colors):
    n = 0

    _,horizontal,_ = imgMatrix.shape
    while (n<horizontal) :
        for interval, color in zip(intervals, colors):
            imgMatrix[:, n: n+interval] = coloring(cutImg(imgMatrix, n, interval),color)
        
            n = n + interval 
    return imgMatrix

# %%
finalImg = drawPattern(baseImg1,intervals,colors)
plt.figure(figsize=(horizontal/my_dpi, vertical/my_dpi), dpi=my_dpi)
plt.imshow(finalImg)
plt.axis('off')
plt.savefig('C:/Users/User/OpenCv/image9.tiff',dpi=my_dpi)

# %%
import numpy as np
import matplotlib.pyplot as plt

vertical = 1080
horizontal = 1920
my_dpi = 100

intervals = [40,80,160]
colors = [
    [0, 0, 0],
    [1, 1, 1],
    [0.945, 0.654, 0.886],
]   
baseImg1 = np.full((vertical,horizontal,3),(255,255,255))

# %%
import numpy as np
import matplotlib.pyplot as plt

vertical = 1080
horizontal = 1920
my_dpi = 100

intervals = [40,80,160]
colors = [
    [0, 0, 0],
    [1, 1, 1],
    [0.941, 0.945, 0.654],
]   
baseImg1 = np.full((vertical,horizontal,3),(255,255,255))

#vertical pattern 
def createBaseImg(vertical, horizontal):
    imgMatrix = np.full((vertical,horizontal,3),(255,255,255))
    return imgMatrix

def cutImg(imgMatrix,n,interval):
    subImgMatrix = imgMatrix[n:n+interval,:]
    return subImgMatrix

def coloring(subImgMatrix,color):
     subImgMatrix = subImgMatrix * color
     return subImgMatrix

def drawPattern(imgMatrix,intervals,colors):
    n = 0

    vertical,_,_ = imgMatrix.shape
    while (n<vertical) :
        for interval, color in zip(intervals, colors):
            imgMatrix[n:n+interval,:] = coloring(cutImg(imgMatrix, n, interval),color)
        
            n = n + interval 
    return imgMatrix

finalImg = drawPattern(baseImg1,intervals,colors)
plt.figure(figsize=(horizontal/my_dpi, vertical/my_dpi), dpi=my_dpi)
plt.imshow(finalImg)
plt.axis('off')
plt.savefig('C:/Users/User/OpenCv/vertical_yellow.tiff',dpi=my_dpi)

# %%
finalImg = drawPattern(baseImg1,intervals,colors)
plt.figure(figsize=(horizontal/my_dpi, vertical/my_dpi), dpi=my_dpi)
plt.imshow(finalImg)
plt.axis('off')
plt.savefig('C:/Users/User/OpenCv/vertical_yellow.tiff',dpi=my_dpi)

# %%
import numpy as np
import matplotlib.pyplot as plt

vertical = 1080
horizontal = 1920
my_dpi = 100

intervals = [40,80,160]
colors = [
    [0, 0, 0],
    [1, 1, 1],
    [0.941, 0.945, 0.654],
]   
baseImg1 = np.full((vertical,horizontal,3),(255,255,255))

#vertical pattern 
def createBaseImg(vertical, horizontal):
    imgMatrix = np.full((vertical,horizontal,3),(255,255,255))
    return imgMatrix

def cutImg(imgMatrix,n,interval):
    subImgMatrix = imgMatrix[n:n+interval,:]
    return subImgMatrix

def coloring(subImgMatrix,color):
     subImgMatrix = subImgMatrix * color
     return subImgMatrix

def drawPattern(imgMatrix,intervals,colors):
    n = 0

    vertical,_,_ = imgMatrix.shape
    while (n<vertical) :
        for interval, color in zip(intervals, colors):
            imgMatrix[n:n+interval,:] = coloring(cutImg(imgMatrix, n, interval),color)
        
            n = n + interval 
    return imgMatrix
    
graph=plt.scatter(10,10,10)
graph.remove()
finalImg = drawPattern(baseImg1,intervals,colors)
plt.figure(figsize=(horizontal/my_dpi, vertical/my_dpi), dpi=my_dpi)
plt.imshow(finalImg)
plt.axis('off')
plt.savefig('C:/Users/User/OpenCv/moveimg_test.gif',dpi=my_dpi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6b19ba42737e> in <module>
#      44 plt.imshow(finalImg)
#      45 plt.axis('off')
# ---> 46 plt.savefig('C:/Users/User/OpenCv/moveimg_test.gif',dpi=my_dpi)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2148
#    2149         # get canvas object and print method for format
# -> 2150         canvas = self._get_output_canvas(backend, format)
#    2151         print_method = getattr(canvas, 'print_%s' % format)
#    2152
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in _get_output_canvas(self, backend, fmt)
#    2077             return self.switch_backends(canvas_class)
#    2078         # Else report error for unsupported format.
# -> 2079         raise ValueError(
#    2080             "Format {!r} is not supported (supported formats: {})"
#    2081             .format(fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#
# ValueError: Format 'gif' is not supported (supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff)
